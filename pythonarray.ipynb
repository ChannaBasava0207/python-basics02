# %%
marks=[12,34,56,78,90]

print(marks[0])
print(marks[4])
# Out:
# 12
# 90

# %%
marks=[12,34,56,78,90]
marks.append(45)
marks.remove(12)
print(marks)
# Out:
# [34, 56, 78, 90, 45]

# %%
marks=[12,34,56,78,90]
for m in marks:
  print(m)
# Out:
# 12
# 34
# 56
# 78
# 90

# %%
marks=[12,34,56,78,90]
total=0
for m in marks:
  total=total+m
  average=total/len(marks)
print(average)
# Out:
# 54.0

# %%
number=[12,34,56,78,32]
largest=number[0]
for n in number:
  if n>largest:
    largest=n
print(largest)
# Out:
# 78

# %%
number=[12,34,57,73,90]
count=0
for n in number:
  if n%2==0:
    count+=1
print(count)
# Out:
# 3

# %%
marks=[12,34,56,78,90]
for m in marks:
  print(m)
# Out:
# 12
# 34
# 56
# 78
# 90

# %%
marks=[12,34,56,78,90]
sum=0
for m in marks:
  sum+=m
print(sum)
# Out:
# 270

# %%
marks=[12,34,56,78,50]
smallest=marks[0]
for m in marks:
  if smallest>m:
    smallest=m
print(smallest)
# Out:
# 12
