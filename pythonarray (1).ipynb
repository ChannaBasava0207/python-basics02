# %%
name="CBMP"
print(len(name))
# Out:
# 4

# %%
name="ChannaBasava"
print(name.upper())
print(name.lower())
# Out:
# CHANNABASAVA
# channabasava

# %%
name="ChannaBasava"
print(name[7])
# Out:
# a

# %%
for i in "python":
  print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
text=input("enter the text:")
count=0
for i in text:
  if i in "aeiouAEIOU":
    count+=1
print(count)
# Out:
# enter the text:ChannaBasava
# 5

# %%
text=input("enter the text:")
rev=""
for i in text:
  rev=i + rev

print(rev)
# Out:
# enter the text:husn
# nsuh
