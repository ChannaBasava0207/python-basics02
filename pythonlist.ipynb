# %%
numbers=[10,20,30,40,50]
print(numbers[1])
numbers[-2]
# Out:
# 20
# 40

# %%
numbers=[10,20,30,40,50]
print(numbers[1:-1])
print(numbers[:4])
print(numbers[2:])
# Out:
# [20, 30, 40]
# [10, 20, 30, 40]
# [30, 40, 50]

# %%
numbers=[10,20,30,40,50]
numbers.append(50)
numbers.insert(1,34)
print(numbers)
# Out:
# [10, 34, 20, 30, 40, 50, 50]

# %%
numbers=[10,20,30,40,50]
numbers.remove(50)
numbers.pop(1)
print(numbers)
# Out:
# [10, 30, 40]

# %%
numbers=[10,2,65,76,12]
numbers.sort()
numbers.sort(reverse=True)
print(numbers)
# Out:
# [76, 65, 12, 10, 2]
